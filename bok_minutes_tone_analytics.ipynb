# %%
import os
import sys
import platform
import pandas as pd

print(sys.version)
print(platform.system())

import re
from datetime import datetime, timedelta
# Out:
# 3.7.0 (default, Jun 28 2018, 07:39:16)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# Darwin

# %%
pd.__version__
# Out:
# '1.1.5'

# %% [markdown]
# ### KoNlPy 설치

# %%
# !pip install konlpy

# %%
import konlpy

# %%
konlpy.__version__
# Out:
# '0.6.0'

# %% [markdown]
# ### Mecab 설치

# %% [markdown]
# mac os 의 경우 라이브러리 연동이 안되어 직접 설치를 해줘야 함
# https://magicode.tistory.com/62
# https://velog.io/@o920/Mecab-%ED%95%9C%EA%B8%80-%ED%98%95%ED%83%9C%EC%86%8C-%EB%B6%84%EC%84%9D%EA%B8%B0-%EC%84%A4%EC%B9%98
# 1) mecab-python-0.996
# 2) mecab-0.996-ko-0.9.2
# 3) mecab-ko-dic-2.1.1-2018020

# %% [markdown]
# 설치 위치 설정은 ./configure prefix=~/.local

# %%
# !pip uninstall mecab-python3

# %%
# !pip install mecab-ko

# %%
# !pip install mecab-ko-dic

# %%
import MeCab

# %%
MeCab.VERSION
# Out:
# '0.996/ko-0.9.0'

# %%
t = MeCab.Tagger ('~/.local/lib/mecab/dic/mecab-ko-dic')

# %%
pos = t.parse('아버지가방에들어가신다.')
print(pos)
# Out:
# 아버지	NNG,*,F,아버지,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 방	NNG,장소,T,방,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 들어가	VV,*,F,들어가,*,*,*,*
# 신다	EP+EF,*,F,신다,Inflect,EP,EF,시/EP/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# EOS

# %%
from konlpy.tag import Mecab

# %%
mecab = Mecab()

# %%
mecab.pos('아버지가방에들어가신다.')
# Out:
# [('아버지', 'NNG'),
#  ('가', 'JKS'),
#  ('방', 'NNG'),
#  ('에', 'JKB'),
#  ('들어가', 'VV'),
#  ('신다', 'EP+EF'),
#  ('.', 'SF')]

# %% [markdown]
# eKoNLPy 설치 (python>=3.8)
# 현재 테스트 환경은 3.7

# %% [markdown]
# 또한 mecab-python-0.996 별도 설치는 3.7 까지만 가능
# python3.8 적용 시점에 PEP440 적용에 따라 pkg 버전 관리 룰이 강화되어 '0.996/ko-0.9.0' 형식의 패키지 설치는 불가
# -> python setup.py install 시점에 InvalidVersion Error 발생

# %%
# !pip install ekonlpy

# %% [markdown]
# 별도 ekonlpy-old 버전을 다운로드 받아 pip install . 실행

# %%
import ekonlpy

# %%
ekonlpy.__version__
# Out:
# '0.0.1'

# %% [markdown]
# 실제 설치된 버전은 0.8.5 버전 임 (pip install 시 나오는 출력 메세지)

# %%
from ekonlpy.tag import Mecab

# %%
mecab = Mecab()

# %%
mecab.pos('금통위는 따라서 물가안정과 병행, 경기상황에 유의하는 금리정책을 펼쳐나가기로 했다고 밝혔다.')
# Out:
# [('금통위', 'NNG'),
#  ('는', 'JX'),
#  ('따라서', 'MAJ'),
#  ('물가', 'NNG'),
#  ('안정', 'NNG'),
#  ('과', 'JC'),
#  ('병행', 'NNG'),
#  (',', 'SC'),
#  ('경기', 'NNG'),
#  ('상황', 'NNG'),
#  ('에', 'JKB'),
#  ('유의', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETM'),
#  ('금리', 'NNG'),
#  ('정책', 'NNG'),
#  ('을', 'JKO'),
#  ('펼쳐', 'VV'),
#  ('나가', 'VX'),
#  ('기', 'ETN'),
#  ('로', 'JKB'),
#  ('했', 'VV'),
#  ('다고', 'EC'),
#  ('밝혔', 'VV'),
#  ('다', 'EF'),
#  ('.', 'SF')]

# %% [markdown]
# ### minutes 데이터 로딩

# %%
minutes_path = './data/minutes/'
df_minutes_path = os.path.join(minutes_path, 'minutes.csv')
df = pd.read_csv(df_minutes_path, encoding='utf-8')

# %%
df
# Out:
#                   filename                mdate                rdate  \
# 0     KO_20180712_20180731  2018-07-12 10:00:00  2018-07-31 16:00:00
# 1     KO_20180712_20180731  2018-07-12 10:00:00  2018-07-31 16:00:00
# 2     KO_20180712_20180731  2018-07-12 10:00:00  2018-07-31 16:00:00
# 3     KO_20180712_20180731  2018-07-12 10:00:00  2018-07-31 16:00:00
# 4     KO_20180712_20180731  2018-07-12 10:00:00  2018-07-31 16:00:00
# ...                    ...                  ...                  ...
# 3635  KO_20180524_20180612  2018-05-24 10:00:00  2018-06-12 16:00:00
# 3636  KO_20180524_20180612  2018-05-24 10:00:00  2018-06-12 16:00:00
# 3637  KO_20180524_20180612  2018-05-24 10:00:00  2018-06-12 16:00:00
# 3638  KO_20180524_20180612  2018-05-24 10:00:00  2018-06-12 16:00:00
# 3639  KO_20180524_20180612  2018-05-24 10:00:00  2018-06-12 16:00:00
#
#                   section  sid  \
# 0      Economic Situation    0
# 1      Economic Situation    1
# 2      Economic Situation    2
# ...

# %% [markdown]
# ### Measuring tones of the minutes

# %%
from ekonlpy.sentiment import MPKO
# Out:
# /Users/assa/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/feature_extraction/image.py:167: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int):
# /Users/assa/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:35: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# ...

# %%
def calc_polarity(scores):
    eps = 1e-6
    pos_score = [1 for s in scores if s > 0]
    neg_score = [-1 for s in scores if s < 0]

    s_pos = sum(pos_score)
    s_neg = sum(neg_score)

    s_pol = ((s_pos + s_neg) * 1.0 /
             ((s_pos - s_neg) + eps))

    return s_pol

# %%
# %%time

minutes_path = './data/minutes'
df_texts_path = os.path.join(minutes_path, 'minutes.csv')
df_tones_path = os.path.join(minutes_path, 'minutes_tones_2018.csv')

df_texts = pd.read_csv(df_texts_path, index_col=None)

mpko_mkt = MPKO(kind=0)
mpko_lex = MPKO(kind=1)

scores = []
for row in df_texts.to_records(index=False):
  filename, mdate, rdate, section, sid, sentence = row
  tokens = mpko_lex.tokenize(sentence)
  tone_lex = mpko_lex.get_score(tokens)['Polarity']
  tokens = mpko_mkt.tokenize(sentence)
  tone_mkt = mpko_mkt.get_score(tokens)['Polarity']
  score = (filename, mdate, rdate, section, sid, tone_mkt, tone_lex)
  scores.append(score)
  
df_score = pd.DataFrame(scores, columns=['filename', 'mdate', 'rdate', 'section', 'sid', 'tone_mkt', 'tone_lex'])

key_cols = ['mdate']
tone_cols = ['tone_mkt', 'tone_lex']
df_result = df_score.groupby(key_cols)[tone_cols].agg(lambda x: calc_polarity(x)).reset_index()
df_result.to_csv(df_tones_path, encoding='utf-8', index=False)
# Out:
# CPU times: user 22.2 s, sys: 554 ms, total: 22.8 s
# Wall time: 25.4 s

# %%
df_result
# Out:
#                   mdate  tone_mkt  tone_lex
# 0   2018-02-27 10:00:00 -0.076923 -0.053254
# 1   2018-04-12 10:00:00 -0.037838  0.170213
# 2   2018-05-24 10:00:00 -0.083799  0.004926
# 3   2018-07-12 10:00:00  0.006135 -0.066667
# 4   2018-08-31 10:00:00 -0.168421 -0.082126
# 5   2018-10-18 10:00:00 -0.146341  0.099415
# 6   2018-11-30 10:00:00 -0.214286 -0.250000
# 7   2019-01-24 10:00:00 -0.172414 -0.202614
# 8   2019-02-28 10:00:00 -0.341772 -0.238095
# 9   2019-04-18 10:00:00 -0.228070 -0.364162
# 10  2019-05-31 10:00:00 -0.409639 -0.317647
# 11  2019-07-18 10:00:00 -0.511628 -0.413043
# 12  2019-08-30 10:00:00 -0.645570 -0.488372

# %%
df_result['mdate'] = pd.to_datetime(df_result['mdate'])
df_result['mdate'] = pd.to_datetime(df_result['mdate'].dt.date)
df_result
# Out:
#         mdate  tone_mkt  tone_lex
# 0  2018-02-27 -0.076923 -0.053254
# 1  2018-04-12 -0.037838  0.170213
# 2  2018-05-24 -0.083799  0.004926
# 3  2018-07-12  0.006135 -0.066667
# 4  2018-08-31 -0.168421 -0.082126
# 5  2018-10-18 -0.146341  0.099415
# 6  2018-11-30 -0.214286 -0.250000
# 7  2019-01-24 -0.172414 -0.202614
# 8  2019-02-28 -0.341772 -0.238095
# 9  2019-04-18 -0.228070 -0.364162
# 10 2019-05-31 -0.409639 -0.317647
# 11 2019-07-18 -0.511628 -0.413043
# 12 2019-08-30 -0.645570 -0.488372

# %%
bok_rate_data = """
2023 	01월 13일 	3.50
2022 	11월 24일 	3.25
2022 	10월 12일 	3.00
2022 	08월 25일 	2.50
2022 	07월 13일 	2.25
2022 	05월 26일 	1.75
2022 	04월 14일 	1.50
2022 	01월 14일 	1.25
2021 	11월 25일 	1.00
2021 	08월 26일 	0.75
2020 	05월 28일 	0.50
2020 	03월 17일 	0.75
2019 	10월 16일 	1.25
2019 	07월 18일 	1.50
2018 	11월 30일 	1.75
2017 	11월 30일 	1.50
2016 	06월 09일 	1.25
2015 	06월 11일 	1.50
2015 	03월 12일 	1.75
2014 	10월 15일 	2.00
2014 	08월 14일 	2.25
2013 	05월 09일 	2.50
2012 	10월 11일 	2.75
2012 	07월 12일 	3.00
2011 	06월 10일 	3.25
2011 	03월 10일 	3.00
2011 	01월 13일 	2.75
2010 	11월 16일 	2.50
2010 	07월 09일 	2.25
2009 	02월 12일 	2.00
2009 	01월 09일 	2.50
2008 	12월 11일 	3.00
2008 	11월 07일 	4.00
2008 	10월 27일 	4.25
2008 	10월 09일 	5.00
2008 	08월 07일 	5.25
2007 	08월 09일 	5.00
2007 	07월 12일 	4.75
2006 	08월 10일 	4.50
2006 	06월 08일 	4.25
2006 	02월 09일 	4.00
2005 	12월 08일 	3.75
2005 	10월 11일 	3.50
2004 	11월 11일 	3.25
2004 	08월 12일 	3.50
2003 	07월 10일 	3.75
2003 	05월 13일 	4.00
2002 	05월 07일 	4.25
"""

# %%
from io import StringIO

csv_stringio = StringIO(bok_rate_data)
df_bok_rate = pd.read_csv(csv_stringio, sep="\t", header=None)
df_bok_rate.columns = ['year', 'month_day', 'bok_rate']
df_bok_rate
# Out:
#     year month_day  bok_rate
# 0   2023  01월 13일       3.50
# 1   2022  11월 24일       3.25
# 2   2022  10월 12일       3.00
# 3   2022  08월 25일       2.50
# 4   2022  07월 13일       2.25
# 5   2022  05월 26일       1.75
# 6   2022  04월 14일       1.50
# 7   2022  01월 14일       1.25
# 8   2021  11월 25일       1.00
# 9   2021  08월 26일       0.75
# 10  2020  05월 28일       0.50
# 11  2020  03월 17일       0.75
# 12  2019  10월 16일       1.25
# 13  2019  07월 18일       1.50
# 14  2018  11월 30일       1.75
# 15  2017  11월 30일       1.50
# 16  2016  06월 09일       1.25
# 17  2015  06월 11일       1.50
# 18  2015  03월 12일       1.75
# 19  2014  10월 15일       2.00
# 20  2014  08월 14일       2.25
# 21  2013  05월 09일       2.50
# 22  2012  10월 11일       2.75
# 23  2012  07월 12일       3.00
# 24  2011  06월 10일       3.25
# 25  2011  03월 10일       3.00
# 26  2011  01월 13일       2.75
# 27  2010  11월 16일       2.50
# 28  2010  07월 09일       2.25
# 29  2009  02월 12일       2.00
# 30  2009  01월 09일       2.50
# ...

# %%
df_bok_rate['year'] = df_bok_rate['year'].astype(str)

# %%
df_bok_rate['date'] = df_bok_rate['year'] + ' ' + df_bok_rate['month_day']
df_bok_rate['date'] = df_bok_rate['date'].str.strip()
df_bok_rate['date']
# Out:
# 0     2023 01월 13일
# 1     2022 11월 24일
# 2     2022 10월 12일
# 3     2022 08월 25일
# 4     2022 07월 13일
# 5     2022 05월 26일
# 6     2022 04월 14일
# 7     2022 01월 14일
# 8     2021 11월 25일
# 9     2021 08월 26일
# 10    2020 05월 28일
# 11    2020 03월 17일
# 12    2019 10월 16일
# 13    2019 07월 18일
# 14    2018 11월 30일
# 15    2017 11월 30일
# 16    2016 06월 09일
# 17    2015 06월 11일
# 18    2015 03월 12일
# 19    2014 10월 15일
# 20    2014 08월 14일
# 21    2013 05월 09일
# 22    2012 10월 11일
# 23    2012 07월 12일
# 24    2011 06월 10일
# 25    2011 03월 10일
# 26    2011 01월 13일
# 27    2010 11월 16일
# 28    2010 07월 09일
# 29    2009 02월 12일
# 30    2009 01월 09일
# 31    2008 12월 11일
# 32    2008 11월 07일
# 33    2008 10월 27일
# 34    2008 10월 09일
# 35    2008 08월 07일
# 36    2007 08월 09일
# 37    2007 07월 12일
# 38    2006 08월 10일
# 39    2006 06월 08일
# 40    2006 02월 09일
# 41    2005 12월 08일
# 42    2005 10월 11일
# 43    2004 11월 11일
# 44    2004 08월 12일
# 45    2003 07월 10일
# 46    2003 05월 13일
# ...

# %%
df_bok_rate['date'] = pd.to_datetime(df_bok_rate['date'], format='%Y %m월 %d일')

# %%
df_bok_rate = df_bok_rate.drop(columns=['year', 'month_day'])
df_bok_rate = df_bok_rate[['date', 'bok_rate']]
df_bok_rate
# Out:
#          date  bok_rate
# 0  2023-01-13      3.50
# 1  2022-11-24      3.25
# 2  2022-10-12      3.00
# 3  2022-08-25      2.50
# 4  2022-07-13      2.25
# 5  2022-05-26      1.75
# 6  2022-04-14      1.50
# 7  2022-01-14      1.25
# 8  2021-11-25      1.00
# 9  2021-08-26      0.75
# 10 2020-05-28      0.50
# 11 2020-03-17      0.75
# 12 2019-10-16      1.25
# 13 2019-07-18      1.50
# 14 2018-11-30      1.75
# 15 2017-11-30      1.50
# 16 2016-06-09      1.25
# 17 2015-06-11      1.50
# 18 2015-03-12      1.75
# 19 2014-10-15      2.00
# 20 2014-08-14      2.25
# 21 2013-05-09      2.50
# 22 2012-10-11      2.75
# 23 2012-07-12      3.00
# 24 2011-06-10      3.25
# 25 2011-03-10      3.00
# 26 2011-01-13      2.75
# 27 2010-11-16      2.50
# 28 2010-07-09      2.25
# 29 2009-02-12      2.00
# 30 2009-01-09      2.50
# 31 2008-12-11      3.00
# 32 2008-11-07      4.00
# 33 2008-10-27      4.25
# 34 2008-10-09      5.00
# 35 2008-08-07      5.25
# 36 2007-08-09      5.00
# ...

# %%
df_merge = pd.merge(df_result, df_bok_rate, how='left', left_on='mdate', right_on='date')
df_merge
# Out:
#         mdate  tone_mkt  tone_lex       date  bok_rate
# 0  2018-02-27 -0.076923 -0.053254        NaT       NaN
# 1  2018-04-12 -0.037838  0.170213        NaT       NaN
# 2  2018-05-24 -0.083799  0.004926        NaT       NaN
# 3  2018-07-12  0.006135 -0.066667        NaT       NaN
# 4  2018-08-31 -0.168421 -0.082126        NaT       NaN
# 5  2018-10-18 -0.146341  0.099415        NaT       NaN
# 6  2018-11-30 -0.214286 -0.250000 2018-11-30      1.75
# 7  2019-01-24 -0.172414 -0.202614        NaT       NaN
# 8  2019-02-28 -0.341772 -0.238095        NaT       NaN
# 9  2019-04-18 -0.228070 -0.364162        NaT       NaN
# 10 2019-05-31 -0.409639 -0.317647        NaT       NaN
# 11 2019-07-18 -0.511628 -0.413043 2019-07-18      1.50
# 12 2019-08-30 -0.645570 -0.488372        NaT       NaN

# %%
df_merge.at[0, 'bok_rate'] = 1.50

# %%
df_merge['bok_rate'] = df_merge['bok_rate'].ffill()
df_merge
# Out:
#         mdate  tone_mkt  tone_lex       date  bok_rate
# 0  2018-02-27 -0.076923 -0.053254        NaT      1.50
# 1  2018-04-12 -0.037838  0.170213        NaT      1.50
# 2  2018-05-24 -0.083799  0.004926        NaT      1.50
# 3  2018-07-12  0.006135 -0.066667        NaT      1.50
# 4  2018-08-31 -0.168421 -0.082126        NaT      1.50
# 5  2018-10-18 -0.146341  0.099415        NaT      1.50
# 6  2018-11-30 -0.214286 -0.250000 2018-11-30      1.75
# 7  2019-01-24 -0.172414 -0.202614        NaT      1.75
# 8  2019-02-28 -0.341772 -0.238095        NaT      1.75
# 9  2019-04-18 -0.228070 -0.364162        NaT      1.75
# 10 2019-05-31 -0.409639 -0.317647        NaT      1.75
# 11 2019-07-18 -0.511628 -0.413043 2019-07-18      1.50
# 12 2019-08-30 -0.645570 -0.488372        NaT      1.50

# %%
df_merge["EMA_short"] = df_merge["tone_mkt"].ewm(span=3, adjust=True).mean()
df_merge["EMA_long"] = df_merge["tone_mkt"].ewm(span=6, adjust=True).mean()
df_merge["MACD"] = df_merge["EMA_short"] - df_merge["EMA_long"]
df_merge["MACD_sig"] = df_merge["MACD"].ewm(span=3, adjust=True).mean()
df_merge["MACD_bool"] = df_merge["MACD"] > df_merge["MACD_sig"]

# %%
df_merge
# Out:
#         mdate  tone_mkt  tone_lex       date  bok_rate  EMA_short  EMA_long  \
# 0  2018-02-27 -0.076923 -0.053254        NaT      1.50  -0.076923 -0.076923
# 1  2018-04-12 -0.037838  0.170213        NaT      1.50  -0.050866 -0.054123
# 2  2018-05-24 -0.083799  0.004926        NaT      1.50  -0.069685 -0.067464
# 3  2018-07-12  0.006135 -0.066667        NaT      1.50  -0.029248 -0.039035
# 4  2018-08-31 -0.168421 -0.082126        NaT      1.50  -0.101079 -0.084446
# 5  2018-10-18 -0.146341  0.099415        NaT      1.50  -0.124069 -0.104839
# 6  2018-11-30 -0.214286 -0.250000 2018-11-30      1.75  -0.169533 -0.139387
# 7  2019-01-24 -0.172414 -0.202614        NaT      1.75  -0.170979 -0.149509
# 8  2019-02-28 -0.341772 -0.238095        NaT      1.75  -0.256543 -0.207235
# 9  2019-04-18 -0.228070 -0.364162        NaT      1.75  -0.242293 -0.213401
# 10 2019-05-31 -0.409639 -0.317647        NaT      1.75  -0.326006 -0.270889
# ...
